# %% [markdown]
# # EDA of B41 and B44+ ACE Violations

# %%
import pandas as pd

# %%
df=pd.read_csv('./data/b41_44sbs_20250922.csv')
print(len(df))
df.head()
# Out:
# 265234
#    Violation ID                                         Vehicle ID  \
# 0     489739163  e8e4dc921004f56c6cc113126ee548719d826bea60d79f...
# 1     489739123  ec5ded0c3d37e99889dd407051cb84e8e22b9628796e1a...
# 2     489738982  c0b1be9effaa8bc7294527e304e7690b44bade4b9db814...
# 3     489738726  29ac3964f9ce780eb676fc914ab3191540634cfe620ea8...
# 4     489738166  186954f59a97c8a059b662d005eeea836d75ed98450509...
#
#          First Occurrence         Last Occurrence  \
# 0  08/20/2025 07:51:40 PM  08/20/2025 08:11:41 PM
# 1  08/20/2025 07:23:07 PM  08/20/2025 08:02:16 PM
# 2  08/20/2025 07:41:43 PM  08/20/2025 08:00:41 PM
# 3  08/20/2025 07:31:27 PM  08/20/2025 07:43:23 PM
# 4  08/20/2025 07:13:48 PM  08/20/2025 07:18:25 PM
#
#                Violation Status        Violation Type Bus Route ID  \
# 0   DRIVER/VEHICLE INFO MISSING  MOBILE DOUBLE PARKED          B41
# 1      EXEMPT - BUS/PARATRANSIT       MOBILE BUS STOP         B44+
# ...

# %%
condition44 = df['Bus Route ID'] == 'B44+'
df44=df[condition44]

print(len(df44))

df44.head()
# Out:
# 171083
#     Violation ID                                         Vehicle ID  \
# 1      489739123  ec5ded0c3d37e99889dd407051cb84e8e22b9628796e1a...
# 7      489737224  b35f186bdc9d160af19e3a73018f00a2c24a4f50854229...
# 19     489734746  12cf6dcc62ec847bc489bcb6cfbfa9e2c545ee87ea0d21...
# 25     489734545  474eb7cbc1862b855e62b9d1deec1e0e1f4c5c1f2d1c8e...
# 28     489734485  f85a9aed099e758c4e2a46274864f596a9136630a4b65d...
#
#           First Occurrence         Last Occurrence  \
# 1   08/20/2025 07:23:07 PM  08/20/2025 08:02:16 PM
# 7   08/20/2025 06:05:20 PM  08/20/2025 06:47:28 PM
# 19  08/20/2025 01:30:56 PM  08/20/2025 01:34:03 PM
# 25  08/20/2025 01:10:28 PM  08/20/2025 01:41:59 PM
# 28  08/20/2025 01:25:21 PM  08/20/2025 01:37:19 PM
#
#                Violation Status        Violation Type Bus Route ID  \
# 1      EXEMPT - BUS/PARATRANSIT       MOBILE BUS STOP         B44+
# 7    EXEMPT - EMERGENCY VEHICLE       MOBILE BUS STOP         B44+
# ...

# %%
condition41 = df['Bus Route ID'] == 'B41'
df41=df[condition41]

print(len(df41))

df41.head()
# Out:
# 94151
#    Violation ID                                         Vehicle ID  \
# 0     489739163  e8e4dc921004f56c6cc113126ee548719d826bea60d79f...
# 2     489738982  c0b1be9effaa8bc7294527e304e7690b44bade4b9db814...
# 3     489738726  29ac3964f9ce780eb676fc914ab3191540634cfe620ea8...
# 4     489738166  186954f59a97c8a059b662d005eeea836d75ed98450509...
# 5     489737938  f7b856c054de7ccced087ad4f9413380ec494e40abc818...
#
#          First Occurrence         Last Occurrence  \
# 0  08/20/2025 07:51:40 PM  08/20/2025 08:11:41 PM
# 2  08/20/2025 07:41:43 PM  08/20/2025 08:00:41 PM
# 3  08/20/2025 07:31:27 PM  08/20/2025 07:43:23 PM
# 4  08/20/2025 07:13:48 PM  08/20/2025 07:18:25 PM
# 5  08/20/2025 06:59:10 PM  08/20/2025 07:06:39 PM
#
#                Violation Status        Violation Type Bus Route ID  \
# 0   DRIVER/VEHICLE INFO MISSING  MOBILE DOUBLE PARKED          B41
# 2      EXEMPT - BUS/PARATRANSIT       MOBILE BUS LANE          B41
# ...

# %%
df44['Month and Year'] = pd.to_datetime(df44['First Occurrence']).dt.strftime('%m/%Y')
df44.drop(columns=['Violation ID','Vehicle ID','Violation Status','Violation Type','First Occurrence','Last Occurrence'], inplace=True) 

print(len(df44))

df44.head()
# Out:
# /tmp/ipykernel_32171/2876452339.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df44['Month and Year'] = pd.to_datetime(df44['First Occurrence']).dt.strftime('%m/%Y')
# 171083
# /tmp/ipykernel_32171/2876452339.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df44['Month and Year'] = pd.to_datetime(df44['First Occurrence']).dt.strftime('%m/%Y')
# /tmp/ipykernel_32171/2876452339.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df44.to_csv('./data/b44_data_cleaned.csv')

# %%
df41['Month and Year'] = pd.to_datetime(df41['First Occurrence']).dt.strftime('%m/%Y')
df41.drop(columns=['Violation ID','Vehicle ID','Violation Status','Violation Type','First Occurrence','Last Occurrence'], inplace=True) 

print(len(df41))

df41.head()
# Out:
# /tmp/ipykernel_32171/1018568103.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df41['Month and Year'] = pd.to_datetime(df41['First Occurrence']).dt.strftime('%m/%Y')
# 94151
# /tmp/ipykernel_32171/1018568103.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df41['Month and Year'] = pd.to_datetime(df41['First Occurrence']).dt.strftime('%m/%Y')
# /tmp/ipykernel_32171/1018568103.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df41.to_csv('./data/b41_data_cleaned.csv')
